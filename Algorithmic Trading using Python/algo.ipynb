,1], index_col=[0], parse_dates=[0])
stocks
# Out:
#              Adj Close                             Close             \
#                   AAPL         GE         KO        AAPL         GE
# Date
# 2010-01-04    6.487534  68.035332  18.645315    7.643214  92.776077
# 2010-01-05    6.498750  68.387634  18.419764    7.656429  93.256470
# 2010-01-06    6.395379  68.035332  18.413233    7.534643  92.776077
# 2010-01-07    6.383555  71.558212  18.367455    7.520714  97.580017
# 2010-01-08    6.425995  73.099449  18.027504    7.570714  99.681740
# ...                ...        ...        ...         ...        ...
# 2022-12-23  131.299820  63.696453  62.360741  131.860001  63.848557
# 2022-12-27  129.477585  64.514175  62.741817  130.029999  64.668228
# 2022-12-28  125.504539  63.836632  62.116455  126.040001  63.989071
# 2022-12-29  129.059372  65.222855  62.487766  129.610001  65.378609
# 2022-12-30  129.378006  65.254013  62.155540  129.929993  65.409836
#
#                              High                                Low  \
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'GE'),
#             ('Adj Close',   'KO'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'GE'),
#             (    'Close',   'KO'),
#             (     'High', 'AAPL'),
#             (     'High',   'GE'),
#             (     'High',   'KO'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'GE'),
#             (      'Low',   'KO'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'GE'),
#             (     'Open',   'KO'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'GE'),
#             (   'Volume',   'KO')],
#            )

# %%
#convert multi-index to one tuple
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'GE'),   ('Adj Close', 'KO'),
#            ('Close', 'AAPL'),       ('Close', 'GE'),       ('Close', 'KO'),
#             ('High', 'AAPL'),        ('High', 'GE'),        ('High', 'KO'),
#              ('Low', 'AAPL'),         ('Low', 'GE'),         ('Low', 'KO'),
#             ('Open', 'AAPL'),        ('Open', 'GE'),        ('Open', 'KO'),
#           ('Volume', 'AAPL'),      ('Volume', 'GE'),      ('Volume', 'KO')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, GE)  (Adj Close, KO)  \
# Date
# 2010-01-04           6.487534        68.035332        18.645315
# 2010-01-05           6.498750        68.387634        18.419764
# 2010-01-06           6.395379        68.035332        18.413233
# 2010-01-07           6.383555        71.558212        18.367455
# 2010-01-08           6.425995        73.099449        18.027504
# ...                       ...              ...              ...
# 2022-12-23         131.299820        63.696453        62.360741
# 2022-12-27         129.477585        64.514175        62.741817
# 2022-12-28         125.504539        63.836632        62.116455
# 2022-12-29         129.059372        65.222855        62.487766
# 2022-12-30         129.378006        65.254013        62.155540
#
#             (Close, AAPL)  (Close, GE)  (Close, KO)  (High, AAPL)  (High, GE)  \
# Date
# 2010-01-04       7.643214    92.776077    28.520000      7.660714   93.917015
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks
# Out:
#              Adj Close                             Close             \
#                   AAPL         GE         KO        AAPL         GE
# Date
# 2010-01-04    6.487534  68.035332  18.645315    7.643214  92.776077
# 2010-01-05    6.498750  68.387634  18.419764    7.656429  93.256470
# 2010-01-06    6.395379  68.035332  18.413233    7.534643  92.776077
# 2010-01-07    6.383555  71.558212  18.367455    7.520714  97.580017
# 2010-01-08    6.425995  73.099449  18.027504    7.570714  99.681740
# ...                ...        ...        ...         ...        ...
# 2022-12-23  131.299820  63.696453  62.360741  131.860001  63.848557
# 2022-12-27  129.477585  64.514175  62.741817  130.029999  64.668228
# 2022-12-28  125.504539  63.836632  62.116455  126.040001  63.989071
# 2022-12-29  129.059372  65.222855  62.487766  129.610001  65.378609
# 2022-12-30  129.378006  65.254013  62.155540  129.929993  65.409836
#
#                              High                                Low  \
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'GE'),
#             ('Adj Close',   'KO'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'GE'),
#             (    'Close',   'KO'),
#             (     'High', 'AAPL'),
#             (     'High',   'GE'),
#             (     'High',   'KO'),
#             (      'Low', 'AAPL'),
#             (      'Low',   
1.830002
# 2022-12-28  126.040001  130.029999 -3.989998
# 2022-12-29  129.610001  126.040001  3.570000
# 2022-12-30  129.929993  129.610001  0.319992
#
# [3272 rows x 3 columns]

# %%
aapl["% Change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833
# ...                ...         ...       ...       ...
# 2022-12-23  131.860001  132.229996 -0.369995 -0.279812
# 2022-12-27  130.029999  131.860001 -1.830002 -1.387837
# 2022-12-28  126.040001  130.029999 -3.989998 -3.068521
# 2022-12-29  129.610001  126.040001  3.570000  2.832434
# 2022-12-30  129.929993  129.610001  0.319992  0.246888
#
# [3272 rows x 4 columns]

# %%
aapl['Diff2'] = aapl.AAPL.diff(periods =1)
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000
# ...                ...         ...       ...       ...       ...
# 2022-12-23  131.860001  132.229996 -0.369995 -0.279812 -0.369995
# 2022-12-27  130.029999  131.860001 -1.830002 -1.387837 -1.830002
# 2022-12-28  126.040001  130.029999 -3.989998 -3.068521 -3.989998
# 2022-12-29  129.610001  126.040001  3.570000  2.832434  3.570000
# 2022-12-30  129.929993  129.610001  0.319992  0.246888  0.319992
#
# [3272 rows x 5 columns]

# %%
aapl["% Change 2"] = aapl.AAPL.pct_change(periods=1)*100
aapl
# Out:
#                   AAPL        lag1      Diff  % Change     Diff2  % Change 2
# Date
# 2010-01-04    7.643214         NaN       NaN       NaN       NaN         NaN
# 2010-01-05    7.656429    7.643214  0.013215  0.172893  0.013215    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632 -0.121786   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871 -0.013929   -0.184871
# 2010-01-08    7.570714    7.520714  0.050000  0.664833  0.050000    0.664833
# ...                ...         ...       ...       ...       ...         ...
# 2022-12-23  131.860001  132.229996 -0.369995 -0.279812 -0.369995   -0.279812
# 2022-12-27  130.029999  131.860001 -1.830002 -1.387837 -1.830002   -1.387837
# 2022-12-28  126.040001  130.029999 -3.989998 -3.068521 -3.989998   -3.068521
# 2022-12-29  129.610001  126.040001  3.570000  2.832434  3.570000    2.832434
# 2022-12-30  129.929993  129.610001  0.319992  0.246888  0.319992    0.246888
#
# [3272 rows x 6 columns]

# %%
del aapl['% Change']

# %%
del aapl['lag1']

# %%
del aapl ['Diff']
del aapl ['Diff2']
aapl
# Out:
#                   AAPL  % Change 2
# Date
# 2010-01-04    7.643214         NaN
# 2010-01-05    7.656429    0.172893
# 2010-01-06    7.534643   -1.590632
# 2010-01-07    7.520714   -0.184871
# 2010-01-08    7.570714    0.664833
# ...                ...         ...
# 2022-12-23  131.860001   -0.279812
# 2022-12-27  130.029999   -1.387837
# 2022-12-28  126.040001   -3.068521
# 2022-12-29  129.610001    2.832434
# 2022-12-30  129.929993    0.246888
#
# [3272 rows x 2 columns]

# %%
aapl.rename(columns = {'% Change 2' : 'Change'}, inplace = True)

# %%
aapl
# Out:
#                   AAPL    Change
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2022-12-23  131.860001 -0.279812
# 2022-12-27  130.029999 -1.387837
# 2022-12-28  126.040001 -3.068521
# 2022-12-29  129.610001  2.832434
# 2022-12-30  129.929993  0.246888
#
# [3272 rows x 2 columns]

# %%
#resampling the data on a monthly basis
aapl.AAPL.resample("M").last()
# Out:
# Date
# 2010-01-31      6.859286
# 2010-02-28      7.307857
# 2010-03-31      8.392857
# 2010-04-30      9.324643
# 2010-05-31      9.174286
#                  ...
# 2022-08-31    157.220001
# 2022-09-30    138.199997
# 2022-10-31    153.339996
# 2022-11-30    148.029999
# 2022-12-31    129.929993
# Freq: M, Name: AAPL, Length: 156, dtype: float64

# %%
#resampling based on the last business date
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2010-01-29          NaN
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
# 2010-05-31    -1.612472
#                 ...
# 2022-08-31    -3.255180
# 2022-09-30   -12.097700
# 2022-10-31    10.955137
# 2022-11-30    -3.462891
# 2022-12-30   -12.227255
# Freq: BM, Name: AAPL, Length: 156, dtype: float64

# %%
aapl
# Out:
#                   AAPL    Change
# Date
# 2010-01-04    7.643214       NaN
# 2010-01-05    7.656429  0.172893
# 2010-01-06    7.534643 -1.590632
# 2010-01-07    7.520714 -0.184871
# 2010-01-08    7.570714  0.664833
# ...                ...       ...
# 2022-12-23  131.860001 -0.279812
# 2022-12-27  130.029999 -1.387837
# 2022-12-28  126.040001 -3.068521
# 2022-12-29  129.610001  2.832434
# 2022-12-30  129.929993  0.246888
#
# [3272 rows x 2 columns]

# %%
ret = aapl.pct_change().dropna()

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3270 entries, 2010-01-06 to 2022-12-30
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAPL    3270 non-null   float64
#  1   Change  3270 non-null   float64
# dtypes: float64(2)
# memory usage: 76.6 KB

# %%
ret['AAPL'].plot(kind="hist", figsize=(12,8), bins=100)
plt.legend(fontsize=12)
plt.show()

# %%
daily_mean_ret = ret['AAPL'].mean()
daily_mean_ret
# Out:
# 0.001030193769831598

# %%
var_daily= ret['AAPL'].var()
var_daily
# Out:
# 0.00032768439007895787

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# 0.01810205485791483

# %%
ret['AAPL'].std()
# Out:
# 0.01810205485791483

# %%
#calculating the annual mean return as we have 252 working days in a year
annual_mean_ret = daily_mean_ret*252
annual_mean_ret
# Out:
# 0.2596088299975627

# %%
annual_var_ret = var_daily*252
annual_var_ret
# Out:
# 0.08257646629989739

# %%
annual_std_ret = np.sqrt(annual_var_ret)
annual_std_ret
# Out:
# 0.2873612122397478

# %%
ret['AAPL'].std()*np.sqrt(252)
# Out:
# 0.2873612122397478

# %%
tickers = ['GE', 'AAPL', 'KO','IBM','DIS','MSFT']

# %%
stocks = yf.download(tickers, start='2010-01-01', end='2023-01-01')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
stocks
# Out:
#              Adj Close                                               \
#                   AAPL        DIS         GE         IBM         KO
# Date
# 2010-01-04    6.487534  27.933920  68.035332   78.345863  18.645311
# 2010-01-05    6.498751  27.864239  68.387634   77.399429  18.419762
# 2010-01-06    6.395378  27.716162  68.035332   76.896652  18.413225
# 2010-01-07    6.383555  27.724874  71.558212   76.630493  18.367462
# 2010-01-08    6.425994  27.768427  73.099449   77.399429  18.027506
# ...                ...        ...        ...         ...        ...
# 2022-12-23  131.299820  88.010002  63.696453  136.478256  62.360737
# 2022-12-27  129.477600  86.370003  64.514175  137.220139  62.741817
# 2022-12-28  125.504539  84.169998  63.836632  134.907776  62.116455
# 2022-12-29  129.059387  87.180000  65.222855  135.909790  62.487762
# 2022-12-30  129.378006  86.879997  65.254013  135.746002  62.155540
#
# ...

# %%
close = stocks.loc[:,'Close'].copy()

# %%
normclose = close.div(close.iloc[0].mul(100))

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS        GE       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729 -0.002495  0.005178 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906 -0.005314 -0.005151 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.000314  0.051780 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648  0.001571  0.021538  0.010035 -0.018509  0.006897
# 2010-01-11 -0.008821 -0.016311  0.009639 -0.010470  0.020308 -0.012720

# %%
ret.describe()
# Out:
#               AAPL          DIS           GE          IBM           KO  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean      0.001030     0.000440     0.000095     0.000135     0.000307
# std       0.018099     0.016435     0.020118     0.014255     0.011097
# min      -0.128647    -0.131632    -0.151592    -0.128507    -0.096725
# 25%      -0.007652    -0.006798    -0.008648    -0.006398    -0.004747
# 50%       0.000865     0.000427     0.000000     0.000326     0.000488
# 75%       0.010640     0.008040     0.008563     0.007037     0.005900
# max       0.119808     0.144123     0.147300     0.113010     0.064796
#
#               MSFT
# count  3271.000000
# mean      0.000760
# std       0.016392
# min      -0.147390
# 25%      -0.007240
# 50%       0.000534
# 75%       0.009028
# max       0.142169

# %%
#change the position of the vertical and horizontal data
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  3271.0  0.001030  0.018099 -0.128647 -0.007652  0.000865  0.010640
# DIS   3271.0  0.000440  0.016435 -0.131632 -0.006798  0.000427  0.008040
# GE    3271.0  0.000095  0.020118 -0.151592 -0.008648  0.000000  0.008563
# IBM   3271.0  0.000135  0.014255 -0.128507 -0.006398  0.000326  0.007037
# KO    3271.0  0.000307  0.011097 -0.096725 -0.004747  0.000488  0.005900
# MSFT  3271.0  0.000760  0.016392 -0.147390 -0.007240  0.000534  0.009028
#
#            max
# AAPL  0.119808
# DIS   0.144123
# GE    0.147300
# IBM   0.113010
# KO    0.064796
# MSFT  0.142169

# %%
summary = ret.describe().T.loc[:,['mean','std']]
summary
# Out:
#           mean       std
# AAPL  0.001030  0.018099
# DIS   0.000440  0.016435
# GE    0.000095  0.020118
# IBM   0.000135  0.014255
# KO    0.000307  0.011097
# MSFT  0.000760  0.016392

# %%
summary['mean'] = summary['mean']*252 
summary['std'] = summary['std']*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.259663  0.287317
# DIS   0.110785  0.260902
# GE    0.024047  0.319360
# IBM   0.033968  0.226295
# KO    0.077394  0.176152
# MSFT  0.191645  0.260214

# %%
summary.plot.scatter(x='std', y='mean', figsize=(12,8), s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,'std']+0.002,summary.loc[i,'mean']+0.002),size=15)
plt.xlabel('Annual Risk(std)', fontsize=15)
plt.ylabel('Annual Return', fontsize=15)
plt.title('Risk/ Return', fontsize=20)
plt.show()

# %% [markdown]
# ## Correlation and Covariance

# %%
ret
# Out:
#                 AAPL       DIS        GE       IBM        KO      MSFT
# Date
# 2010-01-05  0.001729 -0.002495  0.005178 -0.012080 -0.012097  0.000323
# 2010-01-06 -0.015906 -0.005314 -0.005151 -0.006496 -0.000355 -0.006137
# 2010-01-07 -0.001849  0.000314  0.051780 -0.003462 -0.002485 -0.010400
# 2010-01-08  0.006648  0.001571  0.021538  0.010035 -0.018509  0.006897
# 2010-01-11 -0.008821 -0.016311  0.009639 -0.010470  0.020308 -0.012720
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-23 -0.002798  0.015461  0.000245  0.005466  0.007578  0.002267
# 2022-12-27 -0.013878 -0.018634  0.012838  0.005436  0.006111 -0.007414
# 2022-12-28 -0.030685 -0.025472 -0.010502 -0.016852 -0.009967 -0.010255
# 2022-12-29  0.028324  0.035761  0.021715  0.007427  0.005978  0.027630
# 2022-12-30  0.002469 -0.003441  0.000478 -0.001205 -0.005317 -0.004938
#
# [3271 rows x 6 columns]

# %%
ret.cov()
# Out:
#           AAPL       DIS        GE       IBM        KO      MSFT
# AAPL  0.000328  0.000126  0.000128  0.000107  0.000071  0.000177
# DIS   0.000126  0.000270  0.000162  0.000106  0.000084  0.000131
# GE    0.000128  0.000162  0.000405  0.000140  0.000092  0.000122
# IBM   0.000107  0.000106  0.000140  0.000203  0.000077  0.000114
# KO    0.000071  0.000084  0.000092  0.000077  0.000123  0.000078
# MSFT  0.000177  0.000131  0.000122  0.000114  0.000078  0.000269

# %%
ret.corr()
# Out:
#           AAPL       DIS        GE       IBM        KO      MSFT
# AAPL  1.000000  0.424060  0.350903  0.415156  0.352489  0.595650
# DIS   0.424060  1.000000  0.489545  0.450761  0.461784  0.486882
# GE    0.350903  0.489545  1.000000  0.487846  0.412832  0.369248
# IBM   0.415156  0.450761  0.487846  1.000000  0.486299  0.485986
# KO    0.352489  0.461784  0.412832  0.486299  1.000000  0.426982
# MSFT  0.595650  0.486882  0.369248  0.485986  0.426982  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap='Greens', annot=True, annot_kws={'size':15}, vmax=0.6)
plt.show()

# %% [markdown]
# ## Simple and Log Returns

# %%
df = pd.DataFrame(index=[2018,2019,2020],data=[100,50,95],columns =['Price'])

# %%
df
# Out:
#       Price
# 2018    100
# 2019     50
# 2020     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2019   -0.5
# 2020    0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
#mean return are misleading

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2019 -0.693147
# 2020  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)
# Out:
# Price    95.0
# dtype: float64

# %%
msft = yf.download("MSFT")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
msft = msft.Close.to_frame()

# %%
msft
# Out:
#                  Close
# Date
# 1986-03-13    0.097222
# 1986-03-14    0.100694
# 1986-03-17    0.102431
# 1986-03-18    0.099826
# 1986-03-19    0.098090
# ...                ...
# 2023-09-27  312.790009
# 2023-09-28  313.640015
# 2023-09-29  315.750000
# 2023-10-02  321.799988
# 2023-10-03  313.390015
#
# [9466 rows x 1 columns]

# %%
msft.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper right", fontsize=15)
plt.show()

# %%
msft_roll = msft.rolling(window=10)

# %%
msft_roll = msft_roll.mean()

# %%
msft_roll
# Out:
#                  Close
# Date
# 1986-03-13         NaN
# 1986-03-14         NaN
# 1986-03-17         NaN
# 1986-03-18         NaN
# 1986-03-19         NaN
# ...                ...
# 2023-09-27  322.641003
# 2023-09-28  320.135004
# 2023-09-29  318.688004
# 2023-10-02  317.962003
# 2023-10-03  316.436005
#
# [9466 rows x 1 columns]

# %%
msft.rolling(window=10).median()
# Out:
#                  Close
# Date
# 1986-03-13         NaN
# 1986-03-14         NaN
# 1986-03-17         NaN
# 1986-03-18         NaN
# 1986-03-19         NaN
# ...                ...
# 2023-09-27  320.149994
# 2023-09-28  318.535004
# 2023-09-29  317.275009
# 2023-10-02  317.275009
# 2023-10-03  316.380005
#
# [9466 rows x 1 columns]

# %%
msft.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1986-03-13         NaN
# 1986-03-14         NaN
# 1986-03-17         NaN
# 1986-03-18         NaN
# 1986-03-19         NaN
# ...                ...
# 2023-09-27  338.700012
# 2023-09-28  330.220001
# 2023-09-29  329.059998
# 2023-10-02  328.649994
# 2023-10-03  321.799988
#
# [9466 rows x 1 columns]

# %%
msft['SMA50']= msft.rolling(window=50, min_periods=50).mean()

# %%
msft
# Out:
#                  Close       SMA50
# Date
# 1986-03-13    0.097222         NaN
# 1986-03-14    0.100694         NaN
# 1986-03-17    0.102431         NaN
# 1986-03-18    0.099826         NaN
# 1986-03-19    0.098090         NaN
# ...                ...         ...
# 2023-09-27  312.790009  328.785200
# 2023-09-28  313.640015  327.956401
# 2023-09-29  315.750000  327.334001
# 2023-10-02  321.799988  326.894601
# 2023-10-03  313.390015  326.260201
#
# [9466 rows x 2 columns]

# %%
msft.head(52)
# Out:
#                Close     SMA50
# Date
# 1986-03-13  0.097222       NaN
# 1986-03-14  0.100694       NaN
# 1986-03-17  0.102431       NaN
# 1986-03-18  0.099826       NaN
# 1986-03-19  0.098090       NaN
# 1986-03-20  0.095486       NaN
# 1986-03-21  0.092882       NaN
# 1986-03-24  0.090278       NaN
# 1986-03-25  0.092014       NaN
# 1986-03-26  0.094618       NaN
# 1986-03-27  0.096354       NaN
# 1986-03-31  0.095486       NaN
# 1986-04-01  0.094618       NaN
# 1986-04-02  0.095486       NaN
# 1986-04-03  0.096354       NaN
# 1986-04-04  0.096354       NaN
# 1986-04-07  0.094618       NaN
# 1986-04-08  0.095486       NaN
# 1986-04-09  0.097222       NaN
# 1986-04-10  0.098090       NaN
# 1986-04-11  0.099826       NaN
# 1986-04-14  0.100694       NaN
# 1986-04-15  0.100694       NaN
# 1986-04-16  0.104167       NaN
# 1986-04-17  0.105035       NaN
# 1986-04-18  0.101563       NaN
# 1986-04-21  0.101563       NaN
# 1986-04-22  0.099826       NaN
# 1986-04-23  0.100260       NaN
# ...

# %%
msft.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
msft['SMA200']= msft.Close.rolling(window=200, min_periods=200).mean()

# %%
msft.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
#SMA stands for Simple Moving Average for periods

# %%
#EMA stands for Exponential Moving Average

# %%
msft['EMA100']= msft.Close.ewm(span=100, min_periods=100).mean()

# %%
msft
# Out:
#                  Close       SMA50     SMA200      EMA100
# Date
# 1986-03-13    0.097222         NaN        NaN         NaN
# 1986-03-14    0.100694         NaN        NaN         NaN
# 1986-03-17    0.102431         NaN        NaN         NaN
# 1986-03-18    0.099826         NaN        NaN         NaN
# 1986-03-19    0.098090         NaN        NaN         NaN
# ...                ...         ...        ...         ...
# 2023-09-27  312.790009  328.785200  295.48225  320.811300
# 2023-09-28  313.640015  327.956401  295.82335  320.669295
# 2023-09-29  315.750000  327.334001  296.13955  320.571883
# 2023-10-02  321.799988  326.894601  296.46395  320.596202
# 2023-10-03  313.390015  326.260201  296.74480  320.453505
#
# [9466 rows x 4 columns]

# %%
msft.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
msft['Day'] = msft.index.day_name()

# %%
msft['Quarter'] = msft.index.quarter

# %%
MSFT = yf.download('MSFT')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
msft = msft.Close.to_frame()

# %%
all_days = pd.date_range(start='2010-01-01', end='2020-01-01', freq='D')
all_days
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06', '2010-01-07', '2010-01-08',
#                '2010-01-09', '2010-01-10',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3653, freq='D')

# %%
msft.fillna(method='bfill')
# Out:
#                  Close
# Date
# 1986-03-10    0.100694
# 1986-03-17    0.092882
# 1986-03-24    0.096354
# 1986-03-31    0.096354
# 1986-04-07    0.099826
# ...                ...
# 2023-09-04  334.269989
# 2023-09-11  330.220001
# 2023-09-18  317.010010
# 2023-09-25  315.750000
# 2023-10-02  313.390015
#
# [1961 rows x 1 columns]

# %%
msft = yf.download('MSFT', interval='1wk')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
msft
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-03-10    0.088542    0.102431    0.088542    0.100694    0.062553
# 1986-03-17    0.100694    0.103299    0.091146    0.092882    0.057700
# 1986-03-24    0.092882    0.096354    0.089410    0.096354    0.059857
# 1986-03-31    0.096354    0.098958    0.093750    0.096354    0.059857
# 1986-04-07    0.096354    0.101563    0.092882    0.099826    0.062014
# ...                ...         ...         ...         ...         ...
# 2023-09-04  329.000000  336.160004  328.660004  334.269989  334.269989
# 2023-09-11  337.239990  340.859985  329.649994  330.220001  330.220001
# 2023-09-18  327.799988  330.399994  315.000000  317.010010  317.010010
# 2023-09-25  316.589996  319.470001  309.450012  315.750000  315.750000
# 2023-10-02  316.279999  321.890015  311.209991  313.390015  313.390015
#
#                 Volume
# Date
# 1986-03-10  1339948800
# 1986-03-17   367257600
# 1986-03-24   136972800
# ...

# %% [markdown]
# ## Cummalative Returns, Drawdowns etc.

# %%
apple = yf.download('AAPL')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple = apple.Close.to_frame()

# %%
apple
# Out:
#                  Close
# Date
# 1980-12-12    0.128348
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# ...                ...
# 2023-09-27  170.429993
# 2023-09-28  170.690002
# 2023-09-29  171.210007
# 2023-10-02  173.750000
# 2023-10-03  172.399994
#
# [10792 rows x 1 columns]

# %%
#calculating the daily returns of Apple
apple['d_returns']=np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-12    0.128348        NaN
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# ...                ...        ...
# 2023-09-27  170.429993  -0.008937
# 2023-09-28  170.690002   0.001524
# 2023-09-29  171.210007   0.003042
# 2023-10-02  173.750000   0.014727
# 2023-10-03  172.399994  -0.007800
#
# [10792 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  d_returns
# Date
# 1980-12-15    0.121652  -0.053581
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# ...                ...        ...
# 2023-09-27  170.429993  -0.008937
# 2023-09-28  170.690002   0.001524
# 2023-09-29  171.210007   0.003042
# 2023-10-02  173.750000   0.014727
# 2023-10-03  172.399994  -0.007800
#
# [10791 rows x 2 columns]

# %%
apple.d_returns.sum()
# Out:
# 7.202827332346134

# %%
#calculating how much worth the amount invested would be today
np.exp(apple.d_returns.sum())
# Out:
# 1343.2231389453225

# %%
#finding the cummalative returns
apple['cummulative']=apple.d_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  d_returns  cummulative
# Date
# 1980-12-15    0.121652  -0.053581     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261
# 1980-12-17    0.115513   0.024450     0.899998
# 1980-12-18    0.118862   0.028580     0.926092
# 1980-12-19    0.126116   0.059239     0.982610
# ...                ...        ...          ...
# 2023-09-27  170.429993  -0.008937  1327.874233
# 2023-09-28  170.690002   0.001524  1329.900052
# 2023-09-29  171.210007   0.003042  1333.951571
# 2023-10-02  173.750000   0.014727  1353.741466
# 2023-10-03  172.399994  -0.007800  1343.223139
#
# [10791 rows x 3 columns]

# %%
apple.cummulative.plot(figsize=(12,8), title= "APPLE Buy and Hold", fontsize=12)
plt.show()

# %%
#Annual Average Return
apple.d_returns.mean()*252
# Out:
# 0.16820614287380461

# %%
apple.d_returns.std()*np.sqrt(252)
# Out:
# 0.4526945556946183

# %%
#calculating drawdowns
apple['cummax']= apple.cummulative.cummax()

# %%
apple
# Out:
#                  Close  d_returns  cummulative       cummax
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829
# 1980-12-17    0.115513   0.024450     0.899998     0.947829
# 1980-12-18    0.118862   0.028580     0.926092     0.947829
# 1980-12-19    0.126116   0.059239     0.982610     0.982610
# ...                ...        ...          ...          ...
# 2023-09-27  170.429993  -0.008937  1327.874233  1530.604356
# 2023-09-28  170.690002   0.001524  1329.900052  1530.604356
# 2023-09-29  171.210007   0.003042  1333.951571  1530.604356
# 2023-10-02  173.750000   0.014727  1353.741466  1530.604356
# 2023-10-03  172.399994  -0.007800  1343.223139  1530.604356
#
# [10791 rows x 4 columns]

# %%
apple[['cummulative','cummax']].plot(figsize=(12,8), title= "APPLE Buy and Hold + cummax", fontsize=12)
plt.show()

# %%
apple['drawdown']=apple['cummax']-apple['cummulative']

# %%
apple
# Out:
#                  Close  d_returns  cummulative       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-09-27  170.429993  -0.008937  1327.874233  1530.604356  202.730122
# 2023-09-28  170.690002   0.001524  1329.900052  1530.604356  200.704303
# 2023-09-29  171.210007   0.003042  1333.951571  1530.604356  196.652785
# 2023-10-02  173.750000   0.014727  1353.741466  1530.604356  176.862890
# 2023-10-03  172.399994  -0.007800  1343.223139  1530.604356  187.381217
#
# [10791 rows x 5 columns]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402015

# %%
#finding on which date did it take place
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
#A drawdown is a measure used in finance to assess the decline in the value of an investment or asset from its peak to its lowest point before it begins to recover.

# %%
apple.loc[(apple.index <= '2023-01-06')]
# Out:
#                  Close  d_returns  cummulative       cummax    drawdown
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-30  129.929993   0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000  -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001   0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997  -0.010661   974.070524  1418.097708  444.027184
# 2023-01-06  129.619995   0.036133  1009.910574  1418.097708  408.187134
#
# [10606 rows x 5 columns]

# %%
apple['%drawdown'] = (apple['cummax']-apple['cummulative'])/apple['cummax']

# %%
apple
# Out:
#                  Close  d_returns  cummulative       cummax    drawdown  \
# Date
# 1980-12-15    0.121652  -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723  -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513   0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862   0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116   0.059239     0.982610     0.982610    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-09-27  170.429993  -0.008937  1327.874233  1530.604356  202.730122
# 2023-09-28  170.690002   0.001524  1329.900052  1530.604356  200.704303
# 2023-09-29  171.210007   0.003042  1333.951571  1530.604356  196.652785
# 2023-10-02  173.750000   0.014727  1353.741466  1530.604356  176.862890
# 2023-10-03  172.399994  -0.007800  1343.223139  1530.604356  187.381217
#
#             %drawdown
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# ...

# %%
apple['%drawdown'].max()
# Out:
# 0.82216567924191

# %%
apple['%drawdown'].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index <= '1997-12-23')]
# Out:
#                Close  d_returns  cummulative    cummax  drawdown  %drawdown
# Date
# 1980-12-15  0.121652  -0.053581     0.947829  0.947829  0.000000   0.000000
# 1980-12-16  0.112723  -0.076231     0.878261  0.947829  0.069569   0.073398
# 1980-12-17  0.115513   0.024450     0.899998  0.947829  0.047831   0.050464
# 1980-12-18  0.118862   0.028580     0.926092  0.947829  0.021738   0.022934
# 1980-12-19  0.126116   0.059239     0.982610  0.982610  0.000000   0.000000
# ...              ...        ...          ...       ...       ...        ...
# 1997-12-17  0.124442  -0.026549     0.969567  5.060882  4.091315   0.808419
# 1997-12-18  0.123326  -0.009008     0.960872  5.060882  4.100010   0.810137
# 1997-12-19  0.122210  -0.009090     0.952177  5.060882  4.108705   0.811856
# 1997-12-22  0.118862  -0.027778     0.926092  5.060882  4.134790   0.817010
# 1997-12-23  0.115513  -0.028580     0.899998  5.060882  4.160883   0.822166
#
# [4306 rows x 6 columns]

# %% [markdown]
# ## SMA Strategy

# %%
#SMA = Simple Moving Average

# %%
data = apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data = data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-09-27  170.429993
# 2023-09-28  170.690002
# 2023-09-29  171.210007
# 2023-10-02  173.750000
# 2023-10-03  172.399994
#
# [8251 rows x 1 columns]

# %%
sma_s =50
sma_l =100

# %%
data['sma_s']= data.Close.rolling(sma_s).mean()
data['sma_l']= data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-01-02    0.388393         NaN         NaN
# 1991-01-03    0.383929         NaN         NaN
# 1991-01-04    0.386161         NaN         NaN
# 1991-01-07    0.386161         NaN         NaN
# 1991-01-08    0.386161         NaN         NaN
# ...                ...         ...         ...
# 2023-09-27  170.429993  182.192401  182.075901
# 2023-09-28  170.690002  181.704200  182.047101
# 2023-09-29  171.210007  181.265800  182.024201
# 2023-10-02  173.750000  180.902000  182.044001
# 2023-10-03  172.399994  180.495000  182.032401
#
# [8251 rows x 3 columns]

# %%
data.plot(figsize=(12,8),title = 'APPLE - SMA{} | SMA{}'.format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc['2022'].plot(figsize=(12,8),title = 'APPLE - SMA{} | SMA{}'.format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace= True)

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-09-27  170.429993  182.192401  182.075901
# 2023-09-28  170.690002  181.704200  182.047101
# 2023-09-29  171.210007  181.265800  182.024201
# 2023-10-02  173.750000  180.902000  182.044001
# 2023-10-03  172.399994  180.495000  182.032401
#
# [8152 rows x 3 columns]

# %%
data['position'] = np.where(data['sma_s']>data['sma_l'],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  precision  position
# Date
# 1991-05-23    0.402902    0.534420    0.513326          1         1
# 1991-05-24    0.409598    0.530960    0.513538          1         1
# 1991-05-28    0.410714    0.527344    0.513806          1         1
# 1991-05-29    0.419643    0.523638    0.514141          1         1
# 1991-05-30    0.425223    0.519732    0.514531          1         1
# ...                ...         ...         ...        ...       ...
# 2023-09-27  170.429993  182.192401  182.075901          1         1
# 2023-09-28  170.690002  181.704200  182.047101         -1        -1
# 2023-09-29  171.210007  181.265800  182.024201         -1        -1
# 2023-10-02  173.750000  180.902000  182.044001         -1        -1
# 2023-10-03  172.399994  180.495000  182.032401         -1        -1
#
# [8152 rows x 5 columns]

# %%
data.loc["2022",['sma_s','sma_l', 'position']].plot(figsize=(12,8),title = 'APPLE - SMA{} | SMA{}'.format(sma_s,sma_l), fontsize=12, secondary_y = 'position')
# Out:
# <Axes: title={'center': 'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data['returnsb&h']=np.log(data.Close.div(data.Close.shift(1)))

# %%
data['strategy']= data['returnsb&h']*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  precision  position  \
# Date
# 1991-05-23    0.402902    0.534420    0.513326          1         1
# 1991-05-24    0.409598    0.530960    0.513538          1         1
# 1991-05-28    0.410714    0.527344    0.513806          1         1
# 1991-05-29    0.419643    0.523638    0.514141          1         1
# 1991-05-30    0.425223    0.519732    0.514531          1         1
# ...                ...         ...         ...        ...       ...
# 2023-09-27  170.429993  182.192401  182.075901          1         1
# 2023-09-28  170.690002  181.704200  182.047101         -1        -1
# 2023-09-29  171.210007  181.265800  182.024201         -1        -1
# 2023-10-02  173.750000  180.902000  182.044001         -1        -1
# 2023-10-03  172.399994  180.495000  182.032401         -1        -1
#
#             returnsb&h  strategy
# Date
# 1991-05-23         NaN       NaN
# 1991-05-24    0.016483  0.016483
# 1991-05-28    0.002721  0.002721
# ...

# %%
data.dropna(inplace=True)

# %%
data[['returnsb&h','strategy']].sum()
# Out:
# returnsb&h    6.058879
# strategy      2.077183
# dtype: float64

# %%
data[['returnsb&h','strategy']].sum().apply(np.exp) #1$ investment today
# Out:
# returnsb&h    427.895595
# strategy        7.981954
# dtype: float64

# %%
data[['returnsb&h','strategy']].std()*np.sqrt(252) #annual std
# Out:
# returnsb&h    0.436352
# strategy      0.436493
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## Strategy adjusted with Long Bias

# %%
data['position2'] = np.where(data['sma_s']>data['sma_l'],1,0)

# %%
data['strategy2']= data['returnsb&h']*data.position2.shift(1)

# %%
data.dropna(inplace= True)

# %%
data[['returnsb&h','strategy2']].sum()
# Out:
# returnsb&h    6.018168
# strategy2     4.027320
# dtype: float64

# %%
data[['returnsb&h','strategy2']].sum().apply(np.exp) #value today
# Out:
# returnsb&h    410.825363
# strategy2      56.110347
# dtype: float64

# %%
data[['returnsb&h','strategy2']].std()*np.sqrt(252)
# Out:
# returnsb&h    0.436408
# strategy2     0.337459
# dtype: float64

# %%
#This shows us that Strategy 2 is better than Strategy 1

# %%
data[['strategy','strategy2']].std()*np.sqrt(252)
# Out:
# strategy     0.436547
# strategy2    0.337459
# dtype: float64

# %% [markdown]
# ## Creating a Function

# %%
def test_strategy(stock,start,end,SMA):
    df=yf.download(stock,start=start, end=end)
    data = df.Close.to_frame()
    data['returns']=np.log(data.Close.div(data.Close.shift(1)))
    data['SMA_S']=data.Close.rolling(int(SMA[0])).mean()
    data['SMA_L']=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data['position']= np.where(data['SMA_S']>data['SMA_L'],1,-1)
    data['strategy']= data['returns']*data.position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data['strategy'].sum())
    std= data['strategy'].std()*np.sqrt(252)
    
    return ret,std

# %%
test_strategy('TSLA', '2000-01-01','2023-01-01', (50,200))
# Out:
# [*********************100%%**********************]  1 of 1 completed
# (18.20250156588702, 0.5622062188584734)

# %%
#this means that the 1$ invested became 18.20$ with a std of 0.56.

# %% [markdown]
# ## Creating a Class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol = symbol
        self.SMA_S = SMA_S
        self.SMA_L =SMA_L
        self.start= start
        self.end = end
        self.results = None
        self.get_data()
        
    def get_data(self):
        df = yf.download(self.symbol, start=self.start, end=self.end)
        data = df.Close.to_frame()
        data['returns'] = np.log(data.Close.div(data.Close.shift(1)))
        data['SMA_S'] = data.Close.rolling(int(self.SMA_S)).mean()
        data['SMA_L'] = data.Close.rolling(int(self.SMA_L)).mean()
        data.dropna(inplace=True)
        self.data2 = data

        return data

    
    def test_results(self):
        data = self.data2.copy().dropna()
        data['position']= np.where(data['SMA_S']>data['SMA_L'],1,-1)
        data['strategy']= data['returns']*data.position.shift(1)
        data.dropna(inplace=True)
        data['returnsbh']= data['returns'].cumsum().apply(np.exp)
        data['returnsstrategy']= data['strategy'].cumsum().apply(np.exp)
        perf = data['returnsstrategy'].iloc[-1]
        outperf =  perf-data['returnsbh'].iloc[-1]
        
        ret=np.exp(data['strategy'].sum())
        std= data['strategy'].std()*np.sqrt(252)
        
        self.results= data
        
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print('Run the test please')
        else:
            title="{} | SMA_S = {} | SMA_L = {}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[['returnsbh','returnsstrategy']].plot(title=title, figsize=(12,8))

# %%
tester = SMABacktester('NVDA',50,100,'2000-01-01','2023-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (414.193232, 348.327317)

# %%
tester.plot_results()
