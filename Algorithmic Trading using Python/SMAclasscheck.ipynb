# %%
from smabacktest import SMABacktester

# %%
tester = SMABacktester('AAPL',50,250,'2000-01-01', '2023-01-01')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (23.4003, -467.811706)

# %%
tester.plot_results()
